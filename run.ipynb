# %%
# ============================================================
# CSE 5526 - Programming Assignment 2
# Voice Activity Detection in Noise using Deep Learning
# ============================================================

# --- Imports ---
from experiments import run_experiment
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore", message=".*torchaudio.*backend.*", category=UserWarning)
warnings.filterwarnings("ignore", message=".*torchcodec.*AudioDecoder.*", category=UserWarning)

# ============================================================
# run.ipynb
# ============================================================

from experiments import run_experiment
import pandas as pd
import time

results = []

for seq_len in [10, 25, 50, 100]:
    for num_layer in [1, 2, 3]:
        for hidden_unit in [64, 128, 256]:
            for model_name in ["lstm", "bilstm", "cnnlstm"]:
                print(f"\n🧩 Running {model_name.upper()} with seq_len={seq_len}, num_layer={num_layer}, hidden_unit={hidden_unit}")
                start = time.time()
                acc, prec, rec = run_experiment(model_name, n_features=40, hidden_size=hidden_unit, layers=num_layer, seq_len=seq_len)
                end = time.time()
                results.append({
                    "Model": model_name.upper(),
                    "SeqLen": seq_len,
                    "HiddenUnit": hidden_unit,
                    "Layer": num_layer,
                    "Accuracy": acc,
                    "Precision": prec,
                    "Recall": rec,
                    "Time (s)": round(end - start, 1)
                })

# Display results as table
df = pd.DataFrame(results)
display(df)
# Out:
# 🧩 Running LSTM with seq_len=10, num_layer=1, hidden_unit=64
#
# 🚀 Running LSTM model (seq_len=10)...
# 📊 Dataset split: Train=84844, Val=9981, Test=11005
# ✅ DataLoaders ready: Train=1326 batches, Val=156 batches, Test=172 batches
# Epoch 01 | Train Loss: 0.2236 | Val Loss: 0.1427 | Val Acc: 0.9509 (Prec: 0.9536, Rec: 0.9770)
# Epoch 02 | Train Loss: 0.1231 | Val Loss: 0.1062 | Val Acc: 0.9661 (Prec: 0.9648, Rec: 0.9874)
# Epoch 03 | Train Loss: 0.1009 | Val Loss: 0.0899 | Val Acc: 0.9738 (Prec: 0.9739, Rec: 0.9892)
# Epoch 04 | Train Loss: 0.0887 | Val Loss: 0.0804 | Val Acc: 0.9769 (Prec: 0.9750, Rec: 0.9923)
# Epoch 05 | Train Loss: 0.0794 | Val Loss: 0.0750 | Val Acc: 0.9795 (Prec: 0.9782, Rec: 0.9926)
# Epoch 06 | Train Loss: 0.0747 | Val Loss: 0.0755 | Val Acc: 0.9787 (Prec: 0.9760, Rec: 0.9941)
# Epoch 07 | Train Loss: 0.0740 | Val Loss: 0.0726 | Val Acc: 0.9802 (Prec: 0.9763, Rec: 0.9957)
# Epoch 08 | Train Loss: 0.0690 | Val Loss: 0.0688 | Val Acc: 0.9816 (Prec: 0.9777, Rec: 0.9962)
# Epoch 09 | Train Loss: 0.0666 | Val Loss: 0.0689 | Val Acc: 0.9805 (Prec: 0.9773, Rec: 0.9952)
# Epoch 10 | Train Loss: 0.0646 | Val Loss: 0.0609 | Val Acc: 0.9842 (Prec: 0.9842, Rec: 0.9935)
# Epoch 11 | Train Loss: 0.0623 | Val Loss: 0.0587 | Val Acc: 0.9850 (Prec: 0.9818, Rec: 0.9968)
# Epoch 12 | Train Loss: 0.0610 | Val Loss: 0.0583 | Val Acc: 0.9849 (Prec: 0.9812, Rec: 0.9972)
# Epoch 13 | Train Loss: 0.0617 | Val Loss: 0.0608 | Val Acc: 0.9844 (Prec: 0.9822, Rec: 0.9956)
# Epoch 14 | Train Loss: 0.0594 | Val Loss: 0.0546 | Val Acc: 0.9864 (Prec: 0.9832, Rec: 0.9973)
# Epoch 15 | Train Loss: 0.0575 | Val Loss: 0.0549 | Val Acc: 0.9859 (Prec: 0.9816, Rec: 0.9985)
# Epoch 16 | Train Loss: 0.0579 | Val Loss: 0.0561 | Val Acc: 0.9858 (Prec: 0.9819, Rec: 0.9981)
# Epoch 17 | Train Loss: 0.0573 | Val Loss: 0.0539 | Val Acc: 0.9869 (Prec: 0.9832, Rec: 0.9983)
# Epoch 18 | Train Loss: 0.0537 | Val Loss: 0.0527 | Val Acc: 0.9868 (Prec: 0.9844, Rec: 0.9970)
# Epoch 19 | Train Loss: 0.0535 | Val Loss: 0.0510 | Val Acc: 0.9872 (Prec: 0.9843, Rec: 0.9977)
# Epoch 20 | Train Loss: 0.0528 | Val Loss: 0.0561 | Val Acc: 0.9864 (Prec: 0.9824, Rec: 0.9984)
# ✅ Test → Acc: 0.990, Prec: 0.987, Rec: 0.999
#
# 🧩 Running BILSTM with seq_len=10, num_layer=1, hidden_unit=64
#
# 🚀 Running BILSTM model (seq_len=10)...
# 📊 Dataset split: Train=84844, Val=9981, Test=11005
# ✅ DataLoaders ready: Train=1326 batches, Val=156 batches, Test=172 batches
# Epoch 01 | Train Loss: 0.1549 | Val Loss: 0.0779 | Val Acc: 0.9807 (Prec: 0.9783, Rec: 0.9946)
# Epoch 02 | Train Loss: 0.0735 | Val Loss: 0.0764 | Val Acc: 0.9788 (Prec: 0.9825, Rec: 0.9874)
# Epoch 03 | Train Loss: 0.0636 | Val Loss: 0.0595 | Val Acc: 0.9864 (Prec: 0.9820, Rec: 0.9987)
# Epoch 04 | Train Loss: 0.0564 | Val Loss: 0.0592 | Val Acc: 0.9851 (Prec: 0.9797, Rec: 0.9992)
# Epoch 05 | Train Loss: 0.0555 | Val Loss: 0.0502 | Val Acc: 0.9873 (Prec: 0.9833, Rec: 0.9986)
# Epoch 06 | Train Loss: 0.0554 | Val Loss: 0.0507 | Val Acc: 0.9880 (Prec: 0.9844, Rec: 0.9989)
# Epoch 07 | Train Loss: 0.0521 | Val Loss: 0.0459 | Val Acc: 0.9886 (Prec: 0.9848, Rec: 0.9991)
# Epoch 08 | Train Loss: 0.0499 | Val Loss: 0.0499 | Val Acc: 0.9872 (Prec: 0.9826, Rec: 0.9995)
# Epoch 09 | Train Loss: 0.0496 | Val Loss: 0.0509 | Val Acc: 0.9866 (Prec: 0.9819, Rec: 0.9994)
# Epoch 10 | Train Loss: 0.0491 | Val Loss: 0.0472 | Val Acc: 0.9880 (Prec: 0.9839, Rec: 0.9994)
# EARLY STOPPING TRIGGERED
# ✅ Test → Acc: 0.989, Prec: 0.984, Rec: 1.000
#
# 🧩 Running CNNLSTM with seq_len=10, num_layer=1, hidden_unit=64
#
# 🚀 Running CNNLSTM model (seq_len=10)...
# 📊 Dataset split: Train=84844, Val=9981, Test=11005
# ✅ DataLoaders ready: Train=1326 batches, Val=156 batches, Test=172 batches
# Epoch 01 | Train Loss: 0.0996 | Val Loss: 0.0589 | Val Acc: 0.9845 (Prec: 0.9857, Rec: 0.9925)
# Epoch 02 | Train Loss: 0.0547 | Val Loss: 0.0493 | Val Acc: 0.9879 (Prec: 0.9834, Rec: 0.9997)
# Epoch 03 | Train Loss: 0.0499 | Val Loss: 0.0479 | Val Acc: 0.9881 (Prec: 0.9837, Rec: 0.9995)
# Epoch 04 | Train Loss: 0.0496 | Val Loss: 0.0450 | Val Acc: 0.9890 (Prec: 0.9853, Rec: 0.9991)
# Epoch 05 | Train Loss: 0.0466 | Val Loss: 0.0484 | Val Acc: 0.9876 (Prec: 0.9834, Rec: 0.9993)
# Epoch 06 | Train Loss: 0.0470 | Val Loss: 0.0483 | Val Acc: 0.9873 (Prec: 0.9823, Rec: 0.9998)
# Epoch 07 | Train Loss: 0.0468 | Val Loss: 0.0477 | Val Acc: 0.9882 (Prec: 0.9836, Rec: 0.9997)
# EARLY STOPPING TRIGGERED
# ✅ Test → Acc: 0.991, Prec: 0.988, Rec: 1.000
#
# 🧩 Running LSTM with seq_len=10, num_layer=1, hidden_unit=128
#
# 🚀 Running LSTM model (seq_len=10)...
# 📊 Dataset split: Train=84844, Val=9981, Test=11005
# ✅ DataLoaders ready: Train=1326 batches, Val=156 batches, Test=172 batches
# Epoch 01 | Train Loss: 0.2143 | Val Loss: 0.1299 | Val Acc: 0.9557 (Prec: 0.9529, Rec: 0.9854)
# Epoch 02 | Train Loss: 0.1161 | Val Loss: 0.1033 | Val Acc: 0.9693 (Prec: 0.9663, Rec: 0.9905)
# Epoch 03 | Train Loss: 0.0961 | Val Loss: 0.0838 | Val Acc: 0.9750 (Prec: 0.9734, Rec: 0.9918)
# Epoch 04 | Train Loss: 0.0835 | Val Loss: 0.0790 | Val Acc: 0.9784 (Prec: 0.9772, Rec: 0.9927)
# Epoch 05 | Train Loss: 0.0776 | Val Loss: 0.0784 | Val Acc: 0.9790 (Prec: 0.9770, Rec: 0.9935)
# Epoch 06 | Train Loss: 0.0717 | Val Loss: 0.0700 | Val Acc: 0.9810 (Prec: 0.9786, Rec: 0.9947)
# Epoch 07 | Train Loss: 0.0707 | Val Loss: 0.0670 | Val Acc: 0.9821 (Prec: 0.9796, Rec: 0.9951)
# Epoch 08 | Train Loss: 0.0642 | Val Loss: 0.0680 | Val Acc: 0.9816 (Prec: 0.9794, Rec: 0.9948)
# Epoch 09 | Train Loss: 0.0625 | Val Loss: 0.0535 | Val Acc: 0.9865 (Prec: 0.9840, Rec: 0.9969)
# Epoch 10 | Train Loss: 0.0604 | Val Loss: 0.0624 | Val Acc: 0.9845 (Prec: 0.9805, Rec: 0.9978)
# Epoch 11 | Train Loss: 0.0601 | Val Loss: 0.0534 | Val Acc: 0.9860 (Prec: 0.9829, Rec: 0.9974)
# Epoch 12 | Train Loss: 0.0581 | Val Loss: 0.0550 | Val Acc: 0.9856 (Prec: 0.9828, Rec: 0.9967)
# Epoch 13 | Train Loss: 0.0555 | Val Loss: 0.0575 | Val Acc: 0.9847 (Prec: 0.9807, Rec: 0.9977)
# Epoch 14 | Train Loss: 0.0562 | Val Loss: 0.0560 | Val Acc: 0.9857 (Prec: 0.9815, Rec: 0.9984)
# EARLY STOPPING TRIGGERED
# ✅ Test → Acc: 0.989, Prec: 0.986, Rec: 0.998
#
# 🧩 Running BILSTM with seq_len=10, num_layer=1, hidden_unit=128
#
# 🚀 Running BILSTM model (seq_len=10)...
# 📊 Dataset split: Train=84844, Val=9981, Test=11005
# ✅ DataLoaders ready: Train=1326 batches, Val=156 batches, Test=172 batches
# Epoch 01 | Train Loss: 0.1473 | Val Loss: 0.0828 | Val Acc: 0.9791 (Prec: 0.9778, Rec: 0.9929)
# Epoch 02 | Train Loss: 0.0676 | Val Loss: 0.0706 | Val Acc: 0.9839 (Prec: 0.9782, Rec: 0.9993)
# Epoch 03 | Train Loss: 0.0592 | Val Loss: 0.0561 | Val Acc: 0.9863 (Prec: 0.9818, Rec: 0.9990)
# Epoch 04 | Train Loss: 0.0553 | Val Loss: 0.0571 | Val Acc: 0.9855 (Prec: 0.9814, Rec: 0.9979)
# Epoch 05 | Train Loss: 0.0548 | Val Loss: 0.0549 | Val Acc: 0.9853 (Prec: 0.9809, Rec: 0.9982)
# Epoch 06 | Train Loss: 0.0518 | Val Loss: 0.0507 | Val Acc: 0.9868 (Prec: 0.9822, Rec: 0.9991)
# Epoch 07 | Train Loss: 0.0505 | Val Loss: 0.0517 | Val Acc: 0.9862 (Prec: 0.9813, Rec: 0.9994)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 30
#      28 print(f"\n🧩 Running {model_name.upper()} with seq_len={seq_len}, num_layer={num_layer}, hidden_unit={hidden_unit}")
#      29 start = time.time()
# ---> 30 acc, prec, rec = run_experiment(model_name, n_features=40, hidden_size=hidden_unit, layers=num_layer, seq_len=seq_len)
#      31 end = time.time()
#      32 results.append({
#      33     "Model": model_name.upper(),
#      34     "SeqLen": seq_len,
#    (...)     40     "Time (s)": round(end - start, 1)
#      41 })
#
# File c:\Users\anshu\Downloads\Programming Assignment 2\experiments.py:238, in run_experiment(model_name, n_features, hidden_size, layers, seq_len, snr_db)
#     235 model = build_model(model_name, n_features=n_features, hidden_size=hidden_size, num_layers=layers)
#     236 model = model.to(device)
# --> 238 model, hist = train_model(model, train_dl, val_dl, lr=1e-3)
#     240 plt.figure(figsize=(6, 4))
#     241 plt.plot(hist["train_loss"], label="Train")
#
# File c:\Users\anshu\Downloads\Programming Assignment 2\experiments.py:101, in train_model(model, train_dl, val_dl, epochs, lr, patience)
#      99 # TODO: optimizer step and track loss
#     100     optimizer.step()
# --> 101     cumulative_loss += loss.item()
#     103 avg_train_loss = cumulative_loss / len(train_dl)
#     104 train_losses.append(avg_train_loss)
#
# KeyboardInterrupt:
